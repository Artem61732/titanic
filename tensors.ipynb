# %%
import torch

# %%
x = torch.tensor(3.0)
print(x, x.shape)
# Out:
# tensor(3.) torch.Size([])

# %%
x = torch.tensor([[1, 2], [3, 4]])
print(x, x.shape)
print(x.grad)
# Out:
# tensor([[1, 2],
#         [3, 4]]) torch.Size([2, 2])
# None

# %%
print(x + 4)
# Out:
# tensor([[5, 6],
#         [7, 8]])

# %%
print(x*34)
# Out:
# tensor([[ 34,  68],
#         [102, 136]])

# %%
print(x.T)
# Out:
# tensor([[1, 3],
#         [2, 4]])

# %%
x = torch.tensor(3.0, requires_grad=True)
print(x, x.shape)
# Out:
# tensor(3., requires_grad=True) torch.Size([])
